# %% [markdown]
# <a href="https://colab.research.google.com/github/munnecke/chill/blob/main/Chill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Chill is a dialect of English (or others) that uses positive, civil discourse free of toxic languages.  This notebook collects some of the resources and ideas.
#
# Chat GPT:
#
# Designing a language like "Chill" sounds like a fascinating project! To start, we could establish some foundational rules and guidelines, such as:
#
# Vocabulary Selection: Limit the lexicon to words with positive or neutral connotations. Exclude words that are inherently aggressive, derogatory, or inflammatory. We could create a list of approved "Chill" words and their definitions.
#
# Grammar Rules: Emphasize structures that promote clarity, empathy, and understanding. For example, prioritize active listening phrases ("I hear you," "I understand your point") and positive reinforcement ("That's an interesting perspective," "I appreciate your input").
#
# Sentence Construction: Encourage sentences that begin with affirmations or acknowledgments of the other person's feelings or views. Utilize the "Yes, and..." structure from improv to build upon ideas collaboratively rather than confrontationally.
#
# Tone Indicators: Introduce explicit markers or phrases to clarify intent and avoid misunderstandings. For example, adding phrases like "Respectfully" or "From my perspective" to soften statements.
#
# Non-Verbal Elements: Consider including guidelines for digital communication (emojis, tone indicators) to convey the intended civility and emotional nuance.

# %% [markdown]
# Including all of English while filtering out obscenities, curse words, gender-biased language, and racist language makes "Chill" a more inclusive and respectful dialect. Here are a few more ideas to refine this concept:
#
# Dynamic Filtering: Develop a comprehensive list of restricted words and phrases. This list would evolve to accommodate changing societal norms, recognizing that language can shift over time.
#
# Context Sensitivity: Identify words that may not be inherently offensive but could be problematic depending on context. "Chill" could encourage using context indicators to clarify intent, such as "in this context" or "with respect to."
#
# Positive Framing: Encourage language that focuses on solutions, collaboration, and empathy. For example, suggest rephrasing criticisms constructively ("Instead of X, could we try Y?").
#
# Active Encouragement of Inclusive Terms: Promote the use of gender-neutral pronouns ("they/them") and job titles ("firefighter" instead of "fireman").
#
# Tool Development: Consider creating a tool (like a text editor plugin) that highlights or suggests alternatives for any non-Chill words or phrases, guiding users toward more positive and inclusive language choices.

# %% [markdown]
# **Aha!** - Readers may rate a Chill conversation, topic, paragraph, or idea with an Aha!, indicating that it conveyed some insight or idea that the reader wishes to acknowledge as well as record for their own tracking.  Readers will be able to look back on their conversations to rate which of their Chill conversations conveyed the greatest insights, helping them to sort out which participants were most insightful.
#
# Aha!s may also be used to track the evolutionary development of an idea.  For example, someone who read an essay that triggered their own take on the idea could reference the original essay with an Aha!

# %%
# Python dictionary to hold Chill language emoticons
chill_emoticons = {
    "gentle_smile": "😊",     # Friendly, open attitude
    "handshake": "🤝",       # Agreement, collaboration
    "flower": "🌼",          # Kindness, peace
    "meditation": "🧘",      # Calmness, thoughtfulness
    "ear": "👂",             # Active listening
    "hug": "🤗",             # Empathy, support
    "sparkles": "✨",        # Positive outcomes, celebration
    "light_bulb": "💡",      # New ideas, constructive suggestion
    "dove": "🕊️",           # Peaceful dialogue
    "heart": "❤️",          # Appreciation, gratitude
    "raising_hands": "🙌",   # Achievements, agreement
    "rainbow_flag": "🏳️‍🌈"   # Inclusivity, diversity
}

# Example usage:
# Print all Chill emoticons with their meanings
for name, emoticon in chill_emoticons.items():
    print(f"{name}: {emoticon}")
# Out:
# gentle_smile: 😊
# handshake: 🤝
# flower: 🌼
# meditation: 🧘
# ear: 👂
# hug: 🤗
# sparkles: ✨
# light_bulb: 💡
# dove: 🕊️
# heart: ❤️
# raising_hands: 🙌
# rainbow_flag: 🏳️‍🌈

# %% [markdown]
# ![DALL·E 2024-08-31 06.53.38 - An icon design for the 'Chill' language featuring two friendly, non-descript figures facing each other in a positive and open conversation. Keep the s.webp](data:image/webp;base64,...)

# %%
# prompt: the logo of Chill is on my google drive.  this logic loads the logo.

from google.colab import drive
drive.mount('/content/drive')

# Assuming the logo is in the root of your Drive and named "chile_logo.png"
image_path = '/content/drive/MyDrive/Colab Notebooks/Chill/Chill_logo.png'

# Use a library like PIL or OpenCV to load and display the image
from PIL import Image
img = Image.open(image_path)
img.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
